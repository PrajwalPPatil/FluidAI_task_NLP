# %% [markdown]
# <a href="https://colab.research.google.com/github/PrajwalPPatil/FluidAI_task_NLP/blob/main/Fluid_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf
import fitz  # PyMuPDF
import spacy
import re
from collections import defaultdict

# Load NLP model
nlp = spacy.load("en_core_web_sm")

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text("text") + "\n"
    return text

# Function to extract key financial insights
def extract_key_insights(text):
    sections = defaultdict(str)
    keywords = {
        "growth": ["growth", "expansion", "increase", "CAGR", "prospects"],
        "financials": ["revenue", "EBITDA", "profit", "margins", "cash flow"],
        "business_changes": ["acquisition", "merger", "capex", "investment"],
        "risks": ["challenges", "headwinds", "competition", "risk", "slowdown"],
        "strategic_moves": ["strategy", "plans", "future", "vision", "roadmap"]
    }

    for line in text.split("\n"):
        for category, words in keywords.items():
            if any(re.search(fr'\b{word}\b', line, re.IGNORECASE) for word in words):
                sections[category] += line + "\n"
                break

    return sections

# Main function to process the document
pdf_path = "/content/SJS Transcript Call.pdf"
text = extract_text_from_pdf(pdf_path)
insights = extract_key_insights(text)

# Display extracted insights
for category, content in insights.items():
    print(f"\n=== {category.upper()} ===\n{content}")
# Out:
# ...
#
# === BUSINESS_CHANGES ===
# you all about our latest acquisition, Walter Pack India's Performance. Then he will hand it over
# that we have completed the transformative acquisition of Walter Pack India within the set
# After the successful acquisition of Exotech and the robust performance we delivered there in the
# Walter Pack  acquisition has opened up a plethora of new opportunities for us. With this
# acquisition, we have penetrated deeper in passenger vehicles and consumer appliances segment,
# Exotech and Walter Pack acquisition have helped us to balance our portfolio concentration from
# acquisition recently, our cash and cash equivalent stands at 461.7 million and the net debt stands
# end of June '23. However, post Walter Pack India acquisition, it was at Rs.461.7 million, and our
# net debt post-acquisition has increased to Rs.539.8 million and equity share capital has increased
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
